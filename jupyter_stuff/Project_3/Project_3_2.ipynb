# %%
##Import modules
from arcgis.gis import GIS
from arcgis.geocoding import Geocoder, get_geocoders
import pandas as pd
from arcgis.geometry import filters
import arcpy
from fc_to_csv import tableToCSV
import os
import matplotlib.pyplot as plt


#Set GIS with password
gis = GIS("http://slustl.maps.arcgis.com/home", "sspiegel_slu","Apples*200")

# %%
from arcgis.geoenrichment import *
from arcgis.features import SpatialDataFrame
import arcgis

# %%
path = os.getcwd()

# %%
path
# Out:
# 'D:\\Advanced_Class\\jupyter_stuff\\Project_3'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'fc.csv',
#  'fc_to_csv.py',
#  'Project_3.ipynb',
#  'Project_3_2.ipynb',
#  'significant_month.csv',
#  'states.gdb',
#  'Untitled.ipynb',
#  '__pycache__']

# %%
earthquakes = 'significant_month.csv'

# %%
df = pd.read_csv(earthquakes)

# %%
df
# Out:
#                         time  latitude  longitude   depth   mag magType   nst  \
# 0   2018-11-25T16:37:31.410Z   34.3042    45.7402   10.00  6.30     mww   NaN
# 1   2018-11-21T18:21:43.908Z   59.9732  -153.3083  145.50  5.70      ml   NaN
# 2   2018-11-19T20:18:42.510Z   32.2065  -115.2535   10.95  4.82      mw  29.0
# 3   2018-11-18T20:25:45.970Z  -17.8972  -178.9000  533.60  6.70     mww   NaN
# 4   2018-11-15T23:09:01.050Z  -56.2373  -122.0421   10.00  6.30     mww   NaN
# 5   2018-11-15T20:02:21.960Z  -56.7780   -25.3862   10.00  6.30     mww   NaN
# 6   2018-11-11T14:03:59.560Z   15.5653   -49.8719   10.00  6.30     mww   NaN
# 7   2018-11-09T01:49:40.200Z   71.6226   -11.2399   10.00  6.80     mww   NaN
# 8   2018-11-08T21:07:01.460Z  -34.3508   116.8388   10.00  5.20     mww   NaN
# 9   2018-11-01T22:19:51.540Z  -19.5882   -69.2923  102.00  6.20     mww   NaN
# 10  2018-10-30T02:13:39.550Z  -39.0541   174.9766  227.28  6.10     mww   NaN
#
# ...

# %%
earth_coords = df.iloc[:,1:3].values.tolist()

# %%
earth_coords
# Out:
# [[34.3042, 45.7402],
#  [59.9732, -153.3083],
#  [32.2065, -115.2535],
#  [-17.8972, -178.9],
#  [-56.2373, -122.0421],
#  [-56.778, -25.3862],
#  [15.5653, -49.8719],
#  [71.6226, -11.2399],
#  [-34.3508, 116.8388],
#  [-19.5882, -69.2923],
#  [-39.0541, 174.9766]]

# %%
import arcgis

# %%
sdf = SpatialDataFrame(sdf,geometry=[arcgis.geometry.Geometry({'x':r[1], 'y':r[0], 
                    'spatialReference':{'wkid':4326}}) for r in earth_coords])

# %%
sdf=sdf[df.SHAPE.notna()].copy()

# %%
sdf
# Out:
#                         time  latitude  longitude   depth   mag magType   nst  \
# 0   2018-11-25T16:37:31.410Z   34.3042    45.7402   10.00  6.30     mww   NaN
# 1   2018-11-21T18:21:43.908Z   59.9732  -153.3083  145.50  5.70      ml   NaN
# 2   2018-11-19T20:18:42.510Z   32.2065  -115.2535   10.95  4.82      mw  29.0
# 3   2018-11-18T20:25:45.970Z  -17.8972  -178.9000  533.60  6.70     mww   NaN
# 4   2018-11-15T23:09:01.050Z  -56.2373  -122.0421   10.00  6.30     mww   NaN
# 5   2018-11-15T20:02:21.960Z  -56.7780   -25.3862   10.00  6.30     mww   NaN
# 6   2018-11-11T14:03:59.560Z   15.5653   -49.8719   10.00  6.30     mww   NaN
# 7   2018-11-09T01:49:40.200Z   71.6226   -11.2399   10.00  6.80     mww   NaN
# 8   2018-11-08T21:07:01.460Z  -34.3508   116.8388   10.00  5.20     mww   NaN
# 9   2018-11-01T22:19:51.540Z  -19.5882   -69.2923  102.00  6.20     mww   NaN
# 10  2018-10-30T02:13:39.550Z  -39.0541   174.9766  227.28  6.10     mww   NaN
#
# ...

# %%
sdf.reset_index(inplace=True,drop=True)

# %%
gdb = os.path.join(path,'states.gdb')

# %%
type(sdf)
# Out:
# arcgis.features._data.geodataset.geodataframe.SpatialDataFrame

# %%
sdf.to_featureclass(out_location= gdb, out_name='earthquake', skip_invalid=True)# , overwrite=True)
# Out:
# 'D:\\Advanced_Class\\jupyter_stuff\\Project_3\\states.gdb\\earthquake'

# %%
earthquake_fc = os.path.join(gdb,'earthquake')

# %%
arcpy.analysis.Buffer(earthquake_fc,os.path.join(gdb,'earthquake_30_km'), "30 Kilometers", "FULL", "ROUND", "NONE", None, "PLANAR")
# Out:
# <Result 'D:\\Advanced_Class\\jupyter_stuff\\Project_3\\states.gdb\\earthquake_30_km'>

# %%
earthquake_buffer = os.path.join(gdb,'earthquake_30_km')

# %%
countries = get_countries()

# %%
countries
# Out:
# [<Country name:Albania>,
#  <Country name:Algeria>,
#  <Country name:Andorra>,
#  <Country name:Angola>,
#  <Country name:Argentina>,
#  <Country name:Armenia>,
#  <Country name:Aruba>,
#  <Country name:Australia>,
#  <Country name:Austria>,
#  <Country name:Azerbaijan>,
#  <Country name:Bahamas>,
#  <Country name:Bahrain>,
#  <Country name:Bangladesh>,
#  <Country name:Belarus>,
#  <Country name:Belgium>,
#  <Country name:Bermuda>,
#  <Country name:Bolivia>,
#  <Country name:Bosnia and Herzegovina>,
#  <Country name:Botswana>,
#  <Country name:Brazil>,
#  <Country name:Bulgaria>,
#  <Country name:Cameroon>,
#  <Country name:Canada>,
#  <Country name:Cayman Islands>,
#  <Country name:Chile>,
#  <Country name:China>,
#  <Country name:Colombia>,
#  <Country name:Costa Rica>,
#  <Country name:Cote d'Ivoire>,
#  <Country name:Croatia>,
#  <Country name:Cyprus>,
#  <Country name:Czech Republic>,
#  <Country name:Denmark>,
#  <Country name:Dominican Republic>,
#  <Country name:Ecuador>,
# ...
